# %%
import joblib
import pandas as pd
import numpy as np
import preprocessing as pps

# %%
def load_model():
    model = joblib.load('..\\models\\model.pkl')
    return model

model = load_model()

# %%
print(model)
# Out:
# Pipeline(steps=[('ros', RandomOverSampler(random_state=42)),
#                 ('scaler', StandardScaler()),
#                 ('clf',
#                  LogisticRegression(C=10, max_iter=200, random_state=42))])

# %%
data = pd.read_csv(r"../data/dataset.csv")
data_clean_2=pps.clean_data_2(data)
print(data.shape)
print(data_clean_2.shape)
# Out:
# (768, 9)
# (708, 11)

# %%
colonnes_cluster=['Glucose','BloodPressure','BMI','DiabetesPedigreeFunction','Age']

# %%
data_clean_2 = data_clean_2.reset_index(drop=True)

# %%
data_clean_2= pps.make_cluster(data_clean_2,2,colonnes_cluster,True)
data_clean_2.head()
# Out:
#    Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0           0            6      148             72             35        0
# 1           1            1       85             66             29        0
# 2           2            8      183             64              0        0
# 3           3            1       89             66             23       94
# 4           5            5      116             74              0        0
#
#     BMI  DiabetesPedigreeFunction  Age  Insuline_bool  SkinThickness_bool  \
# 0  33.6                     0.627   50              0                   1
# 1  26.6                     0.351   31              0                   1
# 2  23.3                     0.672   32              0                   0
# 3  28.1                     0.167   21              1                   1
# 4  25.6                     0.201   30              0                   0
#
#    cluster
# 0        1
# 1        0
# 2        1
# 3        0
# ...

# %% [markdown]
# On choisit une ligne au dans notre dataset

# %%
n=102

# %%
print(data_clean_2.index)
# Out:
# RangeIndex(start=0, stop=708, step=1)

# %%
test_array = data_clean_2.loc[[n], ['Glucose', 'BloodPressure', 'BMI', 'DiabetesPedigreeFunction', 'Age']]

# Faire la prédiction
prediction = model.predict(test_array)

# Afficher la prédiction et la réalité correspondante
print(test_array)
print()
print(f"Prediction : {prediction[0]}, Réalité : {data_clean_2.loc[n, 'cluster']} difference: {prediction[0]-data_clean_2.loc[n, 'cluster']}")
# Out:
#      Glucose  BloodPressure   BMI  DiabetesPedigreeFunction  Age
# 102      160             54  30.5                     0.588   39
#
# Prediction : 0, Réalité : 0 difference: 0

# %% [markdown]
# Le test ci dessus nous permet de tester notre modèle on choisit n'importe quelle ligne et on compare la valeur du cluster avec la prédiction de notre modèle.
